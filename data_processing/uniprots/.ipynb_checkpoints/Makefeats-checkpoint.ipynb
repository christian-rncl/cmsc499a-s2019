# %% [markdown]
# ## Make conjoint features
# ## Christian Roncal CMSC499A Dr. Leiserson
#
# ### Todo: Make this a python script

# %%
import numpy as np
import pickle
from Bio import SeqIO
from Bio.Alphabet import ProteinAlphabet
import json

# %%
D = pickle.load(open('D.pkl', 'rb'))

# %%
classes = dict.fromkeys(['A', 'G','V'], 1)
classes.update(dict.fromkeys(['I', 'L', 'F', 'P'], 2))
classes.update(dict.fromkeys(['Y', 'M', 'T', 'S'], 3))
classes.update(dict.fromkeys(['H', 'N', 'Q', 'W'], 4))
classes.update(dict.fromkeys(['R', 'K'], 5))
classes.update(dict.fromkeys(['D', 'E'], 6))
classes.update(dict.fromkeys(['C', 'U'], 7))

# %%
def protToClass(p):
    if p == 'X':
        return '-1'
    else:
        return str(classes[p])

def seqToClass(seq):
    return ''.join(list(map(protToClass, seq)))

def normalize(Fi):
    return (Fi - min(Fi)) / max(Fi)

def getFi(D, seq):
    grptoi = {p:i for i,p in enumerate(D)} # group to index mappings
    Fi = np.zeros(len(grptoi.values()))
    
    classSeq = seqToClass(seq)
#     print(classSeq)
    
    for p in D:
        Fi[grptoi[p]] += classSeq.count(''.join(p))

    return normalize(Fi)

# %%
def proteinize(records):
    for r in records:
        r.seq.Alphabet = ProteinAlphabet

# %%
def makeF(records):
    n = len(records)
    
    F = np.zeros((n, 2793 + 1))
    uniprottoi = {}
    itouniprot = {}
    
    
    for i in range(n):
        F[i,:] = np.append(getFi(D, records[i]), [1]) # add bias
        virus_name = records[i].name.split('|')[1]
        uniprottoi[virus_name] = i
        itouniprot[i] = virus_name
        
    return F, uniprottoi, itouniprot

# %%
virus_records = list(SeqIO.parse('virus_prots.fasta', 'fasta'))
human_records = list(SeqIO.parse('human_prots.fasta', 'fasta'))

# %%
proteinize(virus_records)

# %%
print(virus_records[0].name.split('|')[1]) # to get names of viruses
# Out:
# Q9WMX2

# %%
vfeats, vtoi, itov = makeF(virus_records)
# Out:
# (384, 2794)
# sp|Q9WMX2|POLG_HCVCO
# tr|Q1K9H2|Q1K9H2_I33A0
# tr|Q1K9H5|Q1K9H5_I33A0
# sp|P03431|RDRP_I34A1
# sp|Q05322|VP24_EBOZM
# sp|P03496|NS1_I34A1
# sp|P03470|NRAM_I33A0
# sp|P03433|PA_I34A1
# tr|Q67020|Q67020_9INFA
# sp|P03427|PB2_I33A0
# tr|Q6QYB6|Q6QYB6_9HEPC
# sp|P03454|HEMA_I33A0
# sp|P15659|PA_I33A0
# sp|P05780|M2_I33A0
# tr|I6TAG8|I6TAG8_I34A1
# sp|Q99IB8|POLG_HCVJF
# sp|P0C0U1|PB1F2_I34A1
# tr|Q6DP94|Q6DP94_9INFA
# sp|P05777|M1_I33A0
# tr|Q68113|Q68113_9HEPC
# sp|P03428|PB2_I34A1
# tr|Q194T2|Q194T2_9INFA
# tr|Q20MH8|Q20MH8_I33A0
# tr|Q6QZ87|Q6QZ87_9HEPC
# sp|O60508|PRP17_HUMAN
# tr|Q6QZ81|Q6QZ81_9HEPC
# tr|Q8QVZ0|Q8QVZ0_9HEPC
# tr|Q6QYT6|Q6QYT6_9HEPC
# sp|P55265|DSRAD_HUMAN
# sp|P14678|RSMB_HUMAN
# tr|Q6QZA5|Q6QZA5_9HEPC
# tr|B2BUI7|B2BUI7_9INFA
# sp|P09661|RU2A_HUMAN
# tr|Q6QYR7|Q6QYR7_9HEPC
# tr|B4UPA8|B4UPA8_I34A1
# sp|P30910|NS1_I82A8
# sp|Q13573|SNW1_HUMAN
# tr|Q6QZE5|Q6QZE5_9HEPC
# tr|Q6QYJ7|Q6QYJ7_9HEPC
# tr|Q6QZ22|Q6QZ22_9HEPC
# tr|Q6QZ67|Q6QZ67_9HEPC
# sp|P26378|ELAV4_HUMAN
# tr|Q6QZE7|Q6QZE7_9HEPC
# tr|Q6QYB8|Q6QYB8_9HEPC
# sp|Q9ULR0|ISY1_HUMAN
# tr|Q9JGA0|Q9JGA0_9HEPC
# tr|Q9E3D8|Q9E3D8_9HEPC
# tr|Q68123|Q68123_9HEPC
# tr|Q6QYL2|Q6QYL2_9HEPC
# tr|Q1NZ49|Q1NZ49_9INFA
# sp|Q96EY8|MMAB_HUMAN
# tr|Q8B6D3|Q8B6D3_9HEPC
# sp|Q96PV6|LENG8_HUMAN
# sp|P51398|RT29_HUMAN
# tr|Q6QYE6|Q6QYE6_9HEPC
# tr|A3RJH1|A3RJH1_HUMAN
# tr|Q20MD4|Q20MD4_I72A8
# sp|Q1KMD3|HNRL2_HUMAN
# tr|Q6QYQ9|Q6QYQ9_9HEPC
# tr|Q6QZE2|Q6QZE2_9HEPC
# tr|Q6QZ04|Q6QZ04_9HEPC
# sp|P42766|RL35_HUMAN
# sp|Q8TD84|DSCL1_HUMAN
# sp|Q6DPU2|M1_I02A1
# tr|Q1K9I7|Q1K9I7_9INFA
# sp|P14866|HNRPL_HUMAN
# sp|Q8NCA5|FA98A_HUMAN
# tr|Q6QZH2|Q6QZH2_9HEPC
# sp|P62316|SMD2_HUMAN
# tr|Q6QYL0|Q6QYL0_9HEPC
# tr|A4ZNP8|A4ZNP8_I34A1
# tr|Q6QZF2|Q6QZF2_9HEPC
# tr|B4UPB1|B4UPB1_I34A1
# tr|Q6QZ84|Q6QZ84_9HEPC
# sp|Q92499|DDX1_HUMAN
# tr|A3F769|A3F769_HUMAN
# sp|Q9P013|CWC15_HUMAN
# sp|O60506|HNRPQ_HUMAN
# sp|P61254|RL26_HUMAN
# tr|B4URA9|B4URA9_9INFA
# sp|Q9Y6M1|IF2B2_HUMAN
# sp|P36873|PP1G_HUMAN
# tr|O93077|O93077_9HEPC
# tr|Q6QYE8|Q6QYE8_9HEPC
# sp|O00425|IF2B3_HUMAN
# tr|Q6QZ80|Q6QZ80_9HEPC
# sp|Q9NPA8|ENY2_HUMAN
# sp|O95639|CPSF4_HUMAN
# sp|O75934|SPF27_HUMAN
# tr|Q6QYF1|Q6QYF1_9HEPC
# tr|Q5L4H4|Q5L4H4_9INFA
# sp|Q14444|CAPR1_HUMAN
# sp|Q8QPK2|NRAM_I00A0
# tr|Q549M8|Q549M8_HUMAN
# tr|B2R7W3|B2R7W3_HUMAN
# sp|P08579|RU2B_HUMAN
# tr|X5HMX4|X5HMX4_9MONO
# sp|Q9UKM9|RALY_HUMAN
# sp|Q6UN15|FIP1_HUMAN
# tr|A4D8X6|A4D8X6_9INFA
# sp|O43660|PLRG1_HUMAN
# tr|Q9WPH5|Q9WPH5_9HEPC
# sp|Q99729|ROAA_HUMAN
# tr|O90248|O90248_9HEPC
# sp|P35573|GDE_HUMAN
# sp|Q13247|SRSF6_HUMAN
# tr|Q68949|Q68949_9HEPC
# tr|A9QPL8|A9QPL8_EBOZM
# sp|Q9Y224|RTRAF_HUMAN
# tr|Q8QW27|Q8QW27_9HEPC
# sp|Q96I24|FUBP3_HUMAN
# tr|Q81776|Q81776_9HEPC
# sp|Q8WUD4|CCD12_HUMAN
# tr|Q5QF18|Q5QF18_9INFA
# sp|P39019|RS19_HUMAN
# sp|Q9UKV3|ACINU_HUMAN
# sp|Q96DF8|ESS2_HUMAN
# tr|Q8JR21|Q8JR21_I34A1
# sp|P38159|RBMX_HUMAN
# sp|P05455|LA_HUMAN
# sp|Q96G97|BSCL2_HUMAN
# sp|Q16629|SRSF7_HUMAN
# sp|Q12906|ILF3_HUMAN
# sp|Q6PCB5|RSBNL_HUMAN
# tr|Q6DPG0|Q6DPG0_9INFA
# sp|P17844|DDX5_HUMAN
# sp|O43143|DHX15_HUMAN
# sp|Q92900|RENT1_HUMAN
# sp|P08276|NS1_I71A2
# sp|O60832|DKC1_HUMAN
# sp|Q7L2E3|DHX30_HUMAN
# sp|P43243|MATR3_HUMAN
# sp|P51991|ROA3_HUMAN
# sp|O75152|ZC11A_HUMAN
# sp|Q14103|HNRPD_HUMAN
# sp|P46109|CRKL_HUMAN
# sp|P16403|H12_HUMAN
# tr|C3W6D7|C3W6D7_9INFA

# %%
'B4UPB0' in vtoi.keys()
# Out:
# False

# %%
np.savetxt('vfeats.txt', vfeats)

# %%
with open('vtoi.json', 'w') as f:
    json.dump(vtoi, f)
    
with open('itov.json', 'w') as f:
    json.dump(itov, f)

# %%
v = np.loadtxt('vfeats.txt')

# %%
hfeats, htoi, itoh = makeF(human_records)
# Out:
# (3302, 2794)

# %%
with open('htoi.json', 'w') as f:
    json.dump(htoi, f)
    
with open('itoh.json', 'w') as f:
    json.dump(itoh, f)

# %%
np.savetxt('hfeats.txt', hfeats)

# %%
h = np.loadtxt('hfeats.txt')

# %%
h.shape
# Out:
# (3302, 2794)
