# %% [markdown]
# # Processing data - make train matrix / features
# ## Christian Roncal Cmsc499a Dr. Leiserson

# %%
import os 
import pandas as pd
import numpy as np
from utils import *
import re

# %%
os.listdir()
# Out:
# ['utils.py',
#  'influenza',
#  'process_data.ipynb',
#  'flustrains.txt',
#  '.ipynb_checkpoints',
#  'flu_interactions.csv',
#  '__pycache__']

# %% [markdown]
# # 1 load data

# %%
flu_csv = './influenza/flu_phi.csv'

# %%
fludf = pd.read_csv(flu_csv, index_col=0)

# %%
fludf.head()
# Out:
#                                             Pathogen  Taxonomy ID  \
# 0  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
# 1  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
# 2  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
# 3  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
# 4  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
#
#   VirusUniprot Pathogen Protein HumanUniprot Human Protein  \
# 0       P03433        PA_I34A1        P49736   MCM2_HUMAN
# 1       P03466      NCAP_I34A1        P49736   MCM2_HUMAN
# 2       P03428       PB2_I34A1        P49736   MCM2_HUMAN
# 3       P03485        M1_I34A1        P15311   EZRI_HUMAN
# 4       P03485        M1_I34A1        P11142  HSP7C_HUMAN
#
#                Experimental Method  Pubmed ID
# 0  anti bait coimmunoprecipitation   17932485
# 1  anti bait coimmunoprecipitation   17932485
# 2  anti bait coimmunoprecipitation   17932485
# 3  anti bait coimmunoprecipitation   17022977
# 4  anti bait coimmunoprecipitation   17022977

# %%
fludf['Pathogen'].unique()
# Out:
# array(['Influenza A virus STRAIN A / PUERTO RICO / 8 / 1934 (H1N1)',
#        'Influenza A virus STRAIN A / TURKEY / OREGON / 1971 (H7N3)',
#        'Influenza A virus STRAIN A / hvPR8 / 34 (H1N1)',
#        'Influenza A virus STRAIN A / VICTORIA / 3 / 1975 (H3N2)',
#        'Influenza A virus STRAIN A / UDORN / 307 / 1972 (H3N2)',
#        'Influenza A virus STRAIN A / AICHI / 2 / 1968 (H3N2)',
#        'Bacillus anthracis', 'Yersinia pestis',
#        'Human herpesvirus 1 STRAIN 17',
#        'Influenza A virus STRAIN A / Wilson-Smith / 1933 (H1N1)',
#        'Influenza A virus STRAIN A / TEXAS / 36 / 1991 (H1N1)',
#        'Influenza A virus STRAIN A / WSN / 1933 (H1N1)',
#        'Influenza A virus STRAIN A / NEW CALEDONIA / 20 / 1999 (H1N1)',
#        'Influenza A virus STRAIN A / PANAMA / 2007 / 1999 (H3N2)',
#        'Influenza A virus STRAIN A / WYOMING / 03 / 2003 (H3N2)',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE HXB2 ',
#        'Influenza A virus STRAIN A / ENGLAND / 878 / 1969 (H3N2)',
#        'Influenza C virus STRAIN C / ANN ARBOR / 1 / 50',
#        'Influenza A virus STRAIN A / BREVIG MISSION / 1 / 1918 (H1N1)',
#        'Influenza A virus STRAIN A / HONG KONG / 156 / 97 (H5N1)',
#        'Influenza A virus STRAIN A / CHICKEN / NAKORN-PATOM / THAILAND / CU-K2 / 2004 (H5N1)',
#        'Influenza A virus STRAIN A / HICKOX / 1940 (H1N1)',
#        'Influenza A virus STRAIN A / CALIFORNIA / 04 / 2009 (H1N1)',
#        'Influenza A virus STRAIN A / CHICKEN / CHINA / 27402 / 1997 (H5N1)',
#        'La Crosse virus ISOLATE L78',
#        'Influenza A virus STRAIN A / Duck / Hong Kong / 2986.1 / 2000 (H5N1)',
#        'Influenza A virus  STRAIN A / Hatay / 2004 (H5N1)',
#        'Influenza A virus  STRAIN A / Moscow / 10 / 1999 (H3N2)',
#        'Influenza A virus  STRAIN A / California / 08 / 2009 (H1N1)',
#        'Influenza A virus  STRAIN A / Wisconsin / 67 / 2005 (H3N2)',
#        'Influenza A virus  STRAIN A / Solomon Islands / 3 / 2006 (H1N1)',
#        'Influenza A virus  STRAIN A / Vietnam / 1203 / 2004 (H5N1)',
#        'Influenza A virus  STRAIN A / Hong Kong / 482 / 97 (H5N1)',
#        'Vaccinia virus STRAIN WR',
#        'Influenza A virus STRAIN A / WSN / 1933 TS61 (H1N1)',
#        'Influenza A virus STRAIN A / Qa / THAILAND / 57 / 2004 (H5N1)',
#        'Influenza A virus STRAIN A / VIETNAM / 1194 / 2004 (H5N1)',
#        'Influenza A virus STRAIN A / CHICKEN / SCOTLAND / 1959 (H5N1)',
#        'Influenza A virus STRAIN A / UDORN / 1972 (H3N2)',
#        'Influenza A virus STRAIN A / CHICKEN / GUANGDONG / 6 / 97 (H9N2)',
#        'Influenza A virus STRAIN A / CHICKEN / NETHERLANDS / 1 / 03 (H7N7)',
#        'Influenza A virus STRAIN A / CHICKEN / KURGAN / 3 / 2005 (H5N1)',
#        'Influenza A virus STRAIN A / EQUINE / PRAGUE / 1 / 1956 (H7N7)',
#        'Influenza A virus STRAIN A / MIGRATORY DUCK / HONG KONG / MPS180 / 2003 (H4N6)',
#        'Influenza A virus STRAIN A / TURKEY / 651242 / 2006 (H5N1)',
#        'Influenza A virus STRAIN A / VIETNAM / 1196 / 2004 (H5N1)',
#        'Influenza A virus STRAIN A / NEW YORK / 392 / 2004 (H3N2)',
#        'Influenza A virus STRAIN A / HONG KONG / 43 / 1975 (H3N2)',
#        'Influenza A virus STRAIN A / CANTERBURY / 02 / 2005 (H3N2)',
#        'Influenza A virus STRAIN A / MALLARD / NETHERLANDS / 12 / 2000 (H7N3)',
#        'Influenza A virus STRAIN A / NEW YORK / 238 / 2005 (H3N2)',
#        'Influenza A virus STRAIN A / BEIJING / 39 / 1975 (H3N2)',
#        'Influenza A virus STRAIN A / SEAL / MASS / 1 / 1980 (H7N7)',
#        "Human herpesvirus 8 (Kaposi's sarcoma-associated herpesvirus) STRAIN GK18",
#        'Influenza A virus STRAIN A / THAILAND /1 / KAN-1 / 2004 (H5N1)',
#        'Influenza A virus STRAIN A / CHICKEN / ROSTOCK / 45 / 1934 (H7N1)',
#        'Influenza A virus STRAIN A / lvPR8 / 34 (H1N1)',
#        'Influenza A virus STRAIN A / SWINE / WISCONSIN / 1 / 1967 (H1N1)',
#        "Human herpesvirus 8 (Kaposi's sarcoma-associated herpesvirus) ",
#        'Human immunodeficiency virus 1 (HIV1)',
#        'Influenza A virus STRAIN A / NEW YORK / 1682 / 2009 (H1N1)',
#        'Influenza A virus STRAIN A / PARIS / 908 97 (H3N2)',
#        'Influenza A virus STRAIN A / KOL / 2086 / 2009 (H1N1)',
#        'Influenza A virus STRAIN A / REASSORTANT / IGYRP2 (H3N2)',
#        'Influenza A virus STRAIN A / CHICKEN / GUANGDONG / 1 / 2001 (H5N1)',
#        'Influenza A virus STRAIN A / GF / HK / 38 / 2002 (H5N1) ',
#        'Influenza A virus STRAIN A / TURKEY / BETHLEHEM-GLILIT / 1492-B / 1982 (H1N1)',
#        'Influenza A virus STRAIN A / CHICKEN / GERMANY / N / 1949 (H10N7)',
#        'Influenza A virus STRAIN A / TURKEY / CANADA / 1963 (H6N8)',
#        'Influenza B virus STRAIN B / LEE / 1940 ',
#        'Haemophilus influenzae', 'Human papillomavirus TYPE 6b (HPV 6b)',
#        'Human papillomavirus TYPE 11 (HPV 11)',
#        'Mumps virus STRAIN ENDERS',
#        'Rice tungro bacilliform virus (RTBE)', 'Aichi virus 1',
#        'Moloney murine leukemia virus',
#        'Francisella tularensis SUBSPECIES TULARENSIS SCHU S4',
#        'Vesicular stomatitis virus SEROTYPE NEW JERSEY / STRAIN OGDEN',
#        'Canine morbillivirus', 'Rinderpest virus STRAIN RBOK',
#        'Human papillomavirus TYPE 33 (HPV 33)',
#        'Human herpesvirus 4 (Epstein-Barr virus) STRAIN AG876',
#        'Human herpesvirus 5 STRAIN TOLEDO',
#        'Mycobacterium avium STRAIN 104', 'Hepatitis B virus',
#        'Human herpesvirus 4 (Epstein-Barr virus)',
#        'Salmonella enterica SUBSPECIES ENTERICA SEROVAR TYPHIMURIUM STRAIN 14028S',
#        'Chlamydia trachomatis STRAIN A/HAR-13',
#        'Escherichia coli O157:H7',
#        'Bordetella bronchiseptica STRAIN RB50',
#        'Salmonella enterica SUBSPECIES ENTERICA SEROVAR TYPHIMURIUM STRAIN SL1344',
#        'Mesocricetus auratus polyomavirus 1',
#        'African swine fever virus ISOLATE MALAWI LIL 20 / 1',
#        'Mycobacterium tuberculosis STRAIN CDC1551',
#        'Listeria monocytogenes STRAIN 10403S', 'Human adenovirus 41',
#        'Alphapapillomavirus 9',
#        'Crimean-Congo hemorrhagic fever orthonairovirus',
#        'Human papillomavirus TYPE 5 (HPV 5)',
#        'Hepatitis D virus ISOLATE D380', 'Measles virus STRAIN SCHWARZ',
#        'Human papillomavirus TYPE 16 (HPV 16)',
#        'Human papillomavirus TYPE 18 (HPV 18)', 'Human adenovirus 5',
#        'Human papillomavirus TYPE 9 (HPV 9)',
#        'Human herpesvirus 4 (Epstein-Barr virus) STRAIN B95-8',
#        'Human respiratory syncytial virus A2',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE BRU ',
#        "Human herpesvirus 8 (Kaposi's sarcoma-associated herpesvirus) TYPE M",
#        'Variola virus ISOLATE HUMAN / INDIA / Ind3 / 1967', 'Orf virus',
#        'Hepatitis C virus ISOLATE CON1',
#        'Human papillomavirus TYPE 8 (HPV 8)',
#        'Hepatitis B virus GENOTYPE C / SUBTYPE AYR / ISOLATE HUMAN / JAPAN / OKAMOTO',
#        'Escherichia coli STRAIN APEC O1', 'Escherichia coli',
#        'Saccharopolyspora erythraea',
#        'Streptococcus pyogenes SEROTYPE M1',
#        'Human papillomavirus TYPE 3 (HPV 3)',
#        'Human papillomavirus 6 (HPV 6)',
#        'Adeno-associated virus 2 ISOLATE SRIVASTAVA / 1982',
#        'Chikungunya virus', 'Sindbis virus',
#        'Human herpesvirus 1 STRAIN KOS', 'Macaca mulatta polyomavirus 1',
#        'Severe acute respiratory syndrome (SARS) coronavirus',
#        'Semliki forest virus', 'Hepatitis C virus ISOLATE JFH-1',
#        'Dengue virus 2 STRAIN 16681-PDK53',
#        'Murid herpesvirus 4 (Murine herpesvirus 68)',
#        'Simian rotavirus A STRAIN SA11-H96',
#        'Tylonycteris bat coronavirus HKU4',
#        'Pipistrellus bat coronavirus HKU5',
#        'Porcine rotavirus SEROTYPE 5 / STRAIN OSU', 'Nipah virus',
#        'Human parainfluenza virus 2 STRAIN TOSHIBA',
#        'Hendra virus ISOLATE HORSE / AUSTRALIA / HENDRA / 1994',
#        'Mapuera rubulavirus', 'Zaire Ebolavirus STRAIN MAYINGA',
#        'Human T-cell lymphotrophic virus TYPE 2',
#        'Legionella pneumophila SUBSPECIES PNEUMOPHILA STRAIN PHILADEPHIA',
#        'JC polyomavirus',
#        'Human T-lymphotropic virus 1 ISOLATE CARIBBEAN', 'Dengue virus 2',
#        'Japanese encephalitis virus', 'Pseudomonas aeruginosa',
#        'Clostridium sordellii',
#        'Salmonella enterica SUBSPECIES ENTERICA SEROVAR TYPHIMURIUM STRAIN LT2',
#        'Clostridium difficile', 'Shigella flexneri',
#        'Listeria monocytogenes', 'Haemophilus influenzae STRAIN 3655',
#        'Measles virus',
#        'Vibrio cholerae SEROTYPE O1 BIOTYPE El Tor STRAIN N16961',
#        'Escherichia coli K-12', 'Streptomyces sp. KK565',
#        'Marburg virus STRAIN MUSOKE',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE BH10 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE ARV2 / SF2 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE ELI ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE BH5',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE MAL',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE CDC-451',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE MN',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE WMJ2 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE RF / HAT ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE NEW YORK-5',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE JH3 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE Z2 / CDC-Z34 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE NDK',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE JRCSF ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE OYI',
#        'Human immunodeficiency virus 1 (HIV1) STRAIN UGANDAN / ISOLATE U455',
#        'Human immunodeficiency virus 1 ISOLATE YU2',
#        'Plasmodium vivax STRAIN SAL-1', 'Vesicular stomatitis virus', nan,
#        'Human papillomavirus TYPE 1a (HPV 1a)',
#        'Equine arteritis virus STRAIN BUCYRUS',
#        'Classical swine fever virus', 'Bovine viral diarrhea virus 1',
#        'Bovine viral diarrhea virus 2',
#        'Clostridium botulinum F STRAIN LANGELAND',
#        'Vaccinia virus STRAIN L-IPV', 'Vaccinia virus',
#        'Murid herpesvirus 1 STRAIN K181', 'Hepatitis C virus ISOLATE H',
#        'Merkel cell polyomavirus',
#        'Human papillomavirus TYPE 39 (HPV 39)',
#        'Human papillomavirus TYPE 32 (HPV 32)',
#        'Measles virus STRAIN EDMONSTON-B',
#        'Hepatitis C virus ISOLATE TAIWAN', 'Yersinia enterocolitica',
#        'Measles virus STRAIN ICHINOSE-B95a',
#        'Murine polyomavirus (Mouse polyomavirus) STRAIN A2',
#        'Sendai virus STRAIN FUSHIMI',
#        'Human immunodeficiency virus 1 (HIV1) CLONE 12 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE ZAIRE 6',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE BH8 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE ZAIRE 3 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE ZAIRE HZ321 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE Z-84 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE SC ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE BRAIN ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE SF33 ',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE SF162 ',
#        'Human immunodeficiency virus 1 ISOLATE NIT-A',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE HXB3',
#        'Human immunodeficiency virus 1 ISOLATE lw12.3 ',
#        'Rubella virus STRAIN M33', 'Kunjin virus STRAIN MRM61C',
#        'Equine herpesvirus TYPE 1 / STRAIN AB4P',
#        'Hepatitis B virus SUBTYPE ADW4 / STRAIN BRAZIL / ISOLATE W4B',
#        'Simian immunodeficiency virus (SIV) - agm. tan-1',
#        'Chandipura virus STRAIN I653514', 'Abelson murine leukemia virus',
#        'Moloney murine leukemia virus ISOLATE SHINNICK',
#        'Human herpesvirus 3 STRAIN OKA VACCINE',
#        'Hepatitis B virus SUBTYPE ADW2 / STAIN RUTTER / 1979',
#        'Dengue virus 1', 'Human herpesvirus 6 STRAIN Z29',
#        'Rift valley fever virus STRAIN ZH-548 M12',
#        'Acanthamoeba castellanii', 'Human echovirus 7',
#        'Human echovirus 11',
#        'Simian immunodeficiency virus (SIV) ISOLATE AGM / CLONE GRI-1',
#        'Bovine immunodeficiency virus (BIV) ISOLATE R29',
#        'Staphylococcus aureus',
#        'Bovine herpesvirus TYPE 1.1 / STRAIN P8-2',
#        'Human herpesvirus 5 (Human cytomegalovirus) STRAIN MERLIN',
#        'Human herpesvirus 1', 'Human coronavirus NL63',
#        'Reovirus TYPE 1 / STRAIN LANG',
#        'Human immunodeficiency virus 1 ISOLATE 92BR025',
#        'Human foamy virus', 'Mycobacterium tuberculosis STRAIN H37Rv',
#        'Bovine papillomavirus TYPE 1 (BPV 1)', 'Human adenovirus 2',
#        'Murine polyomavirus (Mouse polyomavirus) STRAIN 3',
#        'Human adenovirus 12', 'Hepatitis C virus',
#        'Hepatitis C virus SUBTYPE 1B', 'Human T-lymphotropic virus 1',
#        'Tick-borne encephalitis virus',
#        'Human T-cell leukemia virus 3 STRAIN  Pyl43',
#        'Hepatitis C virus ISOLATE HCR6',
#        'Human T-cell lymphotrophic virus TYPE 1 / STRAIN ATK',
#        'Deltapapillomavirus 4', 'Bovine herpesvirus TYPE 1.1',
#        'Gallid alphaherpesvirus 2', 'Hepatitis E virus STRAIN BURMA',
#        'Junin virus', 'Machupo virus', 'Guanarito virus', 'Sabia virus',
#        'Hepatitis C virus ISOLATE HC-J1', 'Toscana virus',
#        'SFTS virus HB29', 'Dengue virus 2 STRAIN 16681',
#        'Finegoldia magna',
#        'Human immunodeficiency virus 2 (HIV2) ISOLATE BEN',
#        'Human herpesvirus 5 (Human cytomegalovirus) STRAIN TOWNE',
#        'Thogoto virus ISOLATE SiAr 126',
#        'Plasmodium falciparum ISOLATE 3D7',
#        'Dengue virus 2 STRAIN NEW GUINEA C',
#        'Plasmodium falciparum STRAIN HB3',
#        'Francisella tularensis SUBSPECIES TULARENSIS ',
#        'Sandfly fever Sicilian virus',
#        'Human herpesvirus 5 (Human cytomegalovirus) STRAIN AD169',
#        'Human herpesvirus 1 STRAIN F', 'Hepatitis C virus ISOLATE 1',
#        'Suid alphaherpesvirus 1', 'Helicobacter pylori G27',
#        'Vaccinia virus STRAIN COPENHAGEN',
#        'Human herpesvirus 6 STRAIN UGANDA-1102',
#        'Hepatitis C virus ISOLATE JAPANESE', 'Seoul virus STRAIN SR11',
#        'Salmonella enterica SUBSPECIES ENTERICA SEROVAR TYPHIMURIUM',
#        'Hantaan virus STRAIN 76-118',
#        'Human immunodeficiency virus 1 ISOLATE LAI',
#        'Chlamydia trachomatis STRAIN D / UW-3 / CX',
#        'Neisseria meningitidis SEROGROUP B STRAIN MC58',
#        'Porcine reproductive and respiratory syndrome virus (PRRSV)',
#        'Escherichia coli O55:H7 STRAIN CB9615',
#        'Vaccinia virus STRAIN Wyeth', 'Hepatitis C virus ISOLATE HC-J4',
#        'Hepatitis C virus ISOLATE BK', 'Seoul orthohantavirus',
#        'Walleye dermal sarcoma virus',
#        'Mumps virus STRAIN MIYAHARA VACCINE',
#        'Human immunodeficiency virus 1 (HIV1) GROUP M SUBTYPE G ISOLATE SE6165\xa0(HIV-1)',
#        'Rous sarcoma virus STRAIN SCHMIDT-RUPPIN A',
#        'Rous sarcoma virus  STRAIN PRAGUE C',
#        'Hepatitis B virus STRAIN AYW / AUSTRALIA / AUSTKW / 1991',
#        'Vibrio cholerae', 'Human T-lymphotropic virus 1 ISOLATE AFRICAN',
#        'West Nile virus', 'Equine infectious anemia virus CLONE 1369',
#        'Rous sarcoma virus', 'Human metapneumovirus STRAIN CAN97-83',
#        'Human adenovirus 18', 'Human adenovirus  55',
#        'Streptococcus pyogenes', 'Human herpesvirus 2 STRAIN HG52',
#        'Streptococcus dysgalactiae SUBSPECIES EQUISSIMILIS',
#        'Staphylococcus aureus SUBSPECIES AUREUS / STRAIN N315',
#        'Staphylococcus phage 42D.m', 'Human herpesvirus 2 STRAIN 333',
#        'Equine infectious anemia virus CLONE CL22',
#        'Staphylococcus aureus SUBSPECIES AUREUS / STRAIN NCTC 8325',
#        'Murine minute virus STRAIN MVM PROTOTYPE',
#        'Human betacoronavirus 2C EMC / 2012', 'Plasmodium falciparum',
#        'Hepatitis E virus STRAIN MEXICO',
#        'Reovirus TYPE 3/STRAIN DEARING',
#        'Parainfluenza virus 5 (Simian virus 5 ) STRAIN W3 ',
#        'Bovine leukemia virus', 'Vaccinia virus STRAIN ANKARA',
#        'Visna/maedi virus STRAIN KV1772',
#        'Rabies virus STRAIN PASTEUR VACCIN',
#        'Measles virus STRAIN EDMONSTON', 'Bunyamwera virus',
#        'Measles virus STRAIN EDMONSTON-ZAGREB',
#        'Sendai virus STRAIN OHITA', 'Bovine alphaherpesvirus 1',
#        'Human papillomavirus TYPE 31 (HPV 31)',
#        'Cowpox virus STRAIN BRIGHTON RED',
#        'Lymphocytic choriomeningitis virus STRAIN ARMSTRONG',
#        'Aichivirus A', 'Equid alphaherpesvirus 1',
#        'Hepatitis C virus ISOLATE HC-J6',
#        'Avian sarcoma virus STRAIN PR2257', 'Helicobacter pylori',
#        'Equine herpesvirus TYPE 2 / STRAIN 86/87',
#        'Brucella melitensis BIOTYPE 1 STRAIN 16M',
#        'Hepatitis B virus SUBTYPE ADYW',
#        'Escherichia coli O127:H6 STRAIN E2348 / 69', 'Rabbitpox virus',
#        'Vesicular stomatitis Indiana virus STRAIN Orsay',
#        'Human adenovirus E', 'Human adenovirus 9', 'Human adenovirus 31',
#        'Fowl adenovirus 1', 'Human adenovirus 7', 'Murine adenovirus 1',
#        'Human adenovirus 3', 'Human adenovirus 1', 'Human adenovirus 40',
#        'Human mastadenovirus C', 'Human adenovirus F',
#        'Human adenovirus 36', 'Human adenovirus  17',
#        'Human adenovirus  19', 'Human adenovirus  23',
#        'Human adenovirus  24', 'Human adenovirus  28',
#        'Human adenovirus  30', 'Human adenovirus  39',
#        'Human adenovirus  43', 'Human adenovirus  47',
#        'Human adenovirus  37', 'Human mastadenovirus D',
#        'Human adenovirus  51', 'Human adenovirus  58',
#        'Human adenovirus 4', 'Coxsackievirus B3 STRAIN WOODRUFF',
#        'Vesicular stomatitis STRAIN SAN JUAN', 'Aeromonas hydrophila',
#        'Moraxella catarrhalis', 'Escherichia coli STRAIN CFT073',
#        'Campylobacter jejuni', 'Hepatitis B virus SUBTYPE ADW2',
#        'Hepatitis B virus GENOTYPE H SUBTYPE ADW4 ISOLATE NICARAGUA / 2928 NIC / 1997',
#        'Human herpesvirus 2',
#        'Kappapapillomavirus 2 (Papillomavirus sylvilagi) STRAIN KANSAS',
#        'Bovine papillomavirus TYPE 2 (BPV 2)',
#        'Human herpesvirus 5 (Human cytomegalovirus)',
#        'Human immunodeficiency virus 2 (HIV2)',
#        'Equine infectious anemia virus', 'Murid herpesvirus 1',
#        'Newcastle disease virus STRAIN B1 / 48',
#        'Helicobacter pylori 26695',
#        'Candida tropicalis STRAIN ATCC MYA-3404',
#        'Candida parapsilosis STRAIN CDC 317',
#        'Citrobacter rodentium STRAIN ICC168', 'Human polyomavirus 1',
#        'Influenza A virus STRAIN A / QUEENSLAND / 7 /70 (H3N2)',
#        'African swine fever virus (ASFV)',
#        'African swine fever virus (ASFV) STRAIN BA71V',
#        'African swine fever virus ISOLATE WARTHOG / NAMIBIA / WART80 / 1980',
#        'Streptococcus agalactiae STRAIN NEM316', 'Streptococcus mutans',
#        'Kappapapillomavirus 2 (Papillomavirus sylvilagi)',
#        'Papiine herpesvirus 1 (Cercopithecine herpesvirus 12)',
#        'Rous sarcoma virus STRAIN SCHMIDT-RUPPIN D',
#        'Bluetongue virus SEROTYPE 10 / ISOLATE AMERICAN',
#        'Hepatitis B virus GENOTYPE D SUBTYPE AYW ISOLATE FRANCE / TIOLLAIS / 1979',
#        'Myxoma virus STRAIN LAUSANNE', 'Candida albicans',
#        'Candida albicans STRAIN SC5314',
#        'Bordetella pertussis STRAIN Tohama I',
#        'Yersinia pseudotuberculosis STRAIN IP 32953',
#        'Classical swine fever virus ALFORT / 187',
#        'Hog cholera virus STRAIN ALFORT ',
#        'Alkhumra hemorrhagic fever virus', 'Radiomyces spectabilis',
#        'Enterobacteria phage lambda', 'Plasmodium yoelii yoelii',
#        'Simian rotavirus A STRAIN SA11-both', 'Streptococcus GROUP G',
#        'Human immunodeficiency virus 2 (HIV2) ISOLATE ROD',
#        'Chicken anemia virus GERMAN ISOLATE CUXHAVEN-1',
#        'Klebsiella pneumoniae',
#        'Human immunodeficiency virus 1 (HIV1) ISOLATE MFA ',
#        'Human immunodeficiency virus 1 ISOLATE KB-1',
#        'Human immunodeficiency virus 1 ISOLATE WMJ1',
#        'Yaba-like disease virus',
#        'Dengue virus 4 STRAIN Dominica / 814669 / 1981',
#        'Sendai virus  STRAIN Z', 'Herpesvirus saimiri STRAIN 11',
#        'Reston ebolavirus STRAIN Reston (1989)', 'Human herpesvirus 3',
#        'Jaagsiekte sheep retrovirus', 'Murine polyomavirus STRAIN A3',
#        'Edwardsiella tarda', 'Human papillomavirus TYPE 4 (HPV4)',
#        'Human papillomavirus TYPE 20 (HPV20)',
#        'Human papillomavirus TYPE 37 (HPV37)',
#        'Human papillomavirus TYPE 38 (HPV38)',
#        'Human papillomavirus TYPE 92 (HPV92)',
#        'Human papillomavirus TYPE 93 (HPV93)',
#        'Human papillomavirus TYPE 96 (HPV96)',
#        'Classical swine fever virus STRAIN BRESCIA',
#        'Plasmodium falciparum STRAIN CAMP/Malaysia',
#        'Gallid herpesvirus 1 STRAIN MD5',
#        'Human papillomavirus TYPE 58 (HPV 58)',
#        'Human papillomavirus TYPE 45 (HPV 45)',
#        'Human papillomavirus TYPE 35 (HPV35)',
#        'Human papillomavirus TYPE 51 (HPV51)',
#        'Human papillomavirus TYPE 70 (HPV70)',
#        'Human papillomavirus TYPE 68 (HPV68)',
#        'Human papillomavirus TYPE 26 (HPV26)',
#        'Hepatitis D virus ISOLATE AMERICAN', 'Tioman virus',
#        'Porcine rubulavirus', 'Menangle virus', 'Human rubulavirus 2',
#        'Anaplasma phagocytophilum STRAIN HZ',
#        'Human rotavirus SEROTYPE 1 / STRAIN WA',
#        'Streptococcus dysgalactiae', 'Streptococcus equi SUBSPECIES EQUI',
#        'Mycoplasma hyopneumoniae STRAIN J',
#        'Pasteurella multocida SUBSPECIES MULTOCIDA STRAIN PM70',
#        'Mycoplasma hyopneumoniae STRAIN 232', 'Chicken anemia virus',
#        'Orf virus STRAIN SA00', 'Bluetongue virus',
#        'Mycoplasma hyorhinis', 'Theileria annulata',
#        'Fowlpox virus STRAIN NVSL', 'Myxoma virus',
#        'Simian rotavirus A STRAIN SA11-4F',
#        'Herpesvirus saimiri STRAIN 488',
#        'Mason-Pfizer monkey virus  (MPMV)', 'Ateline herpesvirus 3',
#        'Hepatitis B virus SUBTYPE ADR',
#        'Bovine viral diarrhea virus 1 ISOLATE NADL',
#        'Bovine herpesvirus TYPE 1 / STRAIN JURA',
#        'Equine herpesvirus  1 (Equid herpesvirus  1) STRAIN KENTUCKY A ',
#        'Clostridium botulinum',
#        'Bovine herpesvirus TYPE 1.1 (STRAIN COOPER)',
#        'Human orthopneumovirus',
#        'Friend murine leukemia virus ISOLATE FB29',
#        'Encephalomyocarditis virus',
#        'Foot-and-mouth disease virus - TYPE O',
#        'Murine cytomegalovirus STRAIN SMITH',
#        'Dengue virus 1 STRAIN WESTERN PACIFIC',
#        'Human immunodeficiency virus 2 (HIV2) ISOLATE GHANA-1',
#        'Small ruminant morbillivirus',
#        'Salmonella enterica SUBSPECIES ENTERICA SEROVAR TYPHI',
#        'Chromobacterium violaceum STRAIN ATCC 12472',
#        'Human immunodeficiency virus 1 (HIV1) GROUP M SUBTYPE F1 ISOLATE 93BR020',
#        'Human immunodeficiency virus 1 (HIV1) GROUP M SUBTYPE H ISOLATE 90CF056',
#        'Pneumocystis carinii', 'Orf virus STRAIN NZ2',
#        'Ectromelia virus Moscow', 'Human herpesvirus 1 STRAIN PATTON',
#        'Human poliovirus 1 STRAIN SABIN',
#        'Rous sarcoma virus STRAIN H-19', 'Mycoplasma arthritidis',
#        'Streptococcus intermedius', 'Human poliovirus 1',
#        'Hepatitis B virus STRAIN LSH / ISOLATE CHIMPANZEE',
#        'Listeria monocytogenes STRAIN EGD-e',
#        'Helicobacter pylori STRAIN J99', 'Haemophilus influenzae Rd KW20',
#        'Human herpesvirus 6 STRAIN GS',
#        'Human respiratory syncytial virus STRAIN S-2',
#        'Pasteurella multocida', 'Respiratory syncytial virus',
#        'Hepatitis B virus GENOTYPE C SUBTYPE AD ISOLATE JAPAN / S-179 / 1988',
#        'Trypanosoma brucei',
#        'Autographa californica nucleopolyhedrovirus',
#        'Molluscum contagiosum virus 1', 'Bovine gammaherpesvirus 4',
#        'Clostridium phage c-st', 'Clostridium botulinum D phage',
#        'Lassa virus STRAIN JOSIAH',
#        'Dengue virus 4 STRAIN PHILIPPINES / H241 / 1956',
#        'Dengue virus 3 STRAIN PHILIPPINES / H87 / 1956',
#        'Simian immunodeficiency virus (SIV) ISOLATE MM142-83',
#        'Citrobacter rodentium',
#        'Trypanosoma brucei brucei STRAIN TREU927',
#        'Porphyromonas gingivalis STRAIN W83', 'Mycoplasma fermentans',
#        'Neisseria meningitidis',
#        'Clostridium botulinum STRAIN Okra / TYPE B1',
#        'Clostridium tetani STRAIN E88',
#        'Herpes simplex virus TYPE 1 / STRAIN RH2',
#        'Staphylococcus aureus STRAIN Mu50 / ATCC 700699', 'Hendra virus',
#        'Japanese encephalitis virus STRAIN JAOARS982',
#        'Avian myeloblastosis virus (AMV)',
#        'Avian infectious bronchitis virus STRAIN BEAUDETTE',
#        'Avian erythroblastosis virus STRAIN SLOAN-KETTERING'],
#       dtype=object)

# %% [markdown]
# # Extract relevant strains
#
# Use regex to get strains we're interested in

# %%
def regex_selector(name):
#     print(name)
    if type(name) != str: return False
    
    return bool(re.search('H1N1', name))
#     return bool(re.search('H1N1|H3N2|H5N1|H7N3', name))

# %%
fludf = fludf[fludf['Pathogen'].apply(regex_selector)]

# %% [markdown]
# count # of strains

# %%
len(fludf['Pathogen'].unique())
# Out:
# 17

# %%
print(fludf['Pathogen'].unique())
# Out:
# ['Influenza A virus STRAIN A / PUERTO RICO / 8 / 1934 (H1N1)'
#  'Influenza A virus STRAIN A / hvPR8 / 34 (H1N1)'
#  'Influenza A virus STRAIN A / Wilson-Smith / 1933 (H1N1)'
#  'Influenza A virus STRAIN A / TEXAS / 36 / 1991 (H1N1)'
#  'Influenza A virus STRAIN A / WSN / 1933 (H1N1)'
#  'Influenza A virus STRAIN A / NEW CALEDONIA / 20 / 1999 (H1N1)'
#  'Influenza A virus STRAIN A / BREVIG MISSION / 1 / 1918 (H1N1)'
#  'Influenza A virus STRAIN A / HICKOX / 1940 (H1N1)'
#  'Influenza A virus STRAIN A / CALIFORNIA / 04 / 2009 (H1N1)'
#  'Influenza A virus  STRAIN A / California / 08 / 2009 (H1N1)'
#  'Influenza A virus  STRAIN A / Solomon Islands / 3 / 2006 (H1N1)'
#  'Influenza A virus STRAIN A / WSN / 1933 TS61 (H1N1)'
#  'Influenza A virus STRAIN A / lvPR8 / 34 (H1N1)'
#  'Influenza A virus STRAIN A / SWINE / WISCONSIN / 1 / 1967 (H1N1)'
#  'Influenza A virus STRAIN A / NEW YORK / 1682 / 2009 (H1N1)'
#  'Influenza A virus STRAIN A / KOL / 2086 / 2009 (H1N1)'
#  'Influenza A virus STRAIN A / TURKEY / BETHLEHEM-GLILIT / 1492-B / 1982 (H1N1)']

# %%
len(fludf)
# Out:
# 10169

# %%
fludf.head()
# Out:
#                                             Pathogen  Taxonomy ID  \
# 0  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
# 1  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
# 2  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
# 3  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
# 4  Influenza A virus STRAIN A / PUERTO RICO / 8 /...       211044
#
#   VirusUniprot Pathogen Protein HumanUniprot Human Protein  \
# 0       P03433        PA_I34A1        P49736   MCM2_HUMAN
# 1       P03466      NCAP_I34A1        P49736   MCM2_HUMAN
# 2       P03428       PB2_I34A1        P49736   MCM2_HUMAN
# 3       P03485        M1_I34A1        P15311   EZRI_HUMAN
# 4       P03485        M1_I34A1        P11142  HSP7C_HUMAN
#
#                Experimental Method  Pubmed ID
# 0  anti bait coimmunoprecipitation   17932485
# 1  anti bait coimmunoprecipitation   17932485
# 2  anti bait coimmunoprecipitation   17932485
# 3  anti bait coimmunoprecipitation   17022977
# 4  anti bait coimmunoprecipitation   17022977

# %% [markdown]
# ### Drop cols we don't need

# %%
# drop cols we don't need
fludf = fludf[['VirusUniprot', 'HumanUniprot']]

# %%
fludf.head()
# Out:
#   VirusUniprot HumanUniprot
# 0       P03433       P49736
# 1       P03466       P49736
# 2       P03428       P49736
# 3       P03485       P15311
# 4       P03485       P11142

# %%
len(fludf['VirusUniprot'].unique())
# Out:
# 141

# %% [markdown]
# # Make interaction matrix

# %% [markdown]
# get unique uniprots

# %%
virus_uniprots = fludf['VirusUniprot'].unique()
human_uniprots = fludf['HumanUniprot'].unique()

# %% [markdown]
# numericalize

# %%
vtoi = {v:i for i,v in enumerate(virus_uniprots)}
itov = {i:v for i,v in enumerate(virus_uniprots)}
htoi = {h:i for i,h in enumerate(human_uniprots)}
itoh = {i:h for i,h in enumerate(human_uniprots)}

# %%
num_virus_uniprots = np.asarray([vtoi[v] for v in virus_uniprots])
num_human_uniprots = np.asarray([htoi[h] for h in human_uniprots])

# %%
def make_numerical_df(vtoi, htoi, df):
    vals = df.values
    d = {'v_idx':[], 'h_idx':[]}
    
    for row in vals:
        d['v_idx'].append(vtoi[row[0]])
        d['h_idx'].append(htoi[row[1]])
        
    return pd.DataFrame(d)

# %%
numdf = make_numerical_df(vtoi, htoi, fludf)

# %%
import multiprocessing as mp
import os

def mp_pairmatcher(v, human_idxs, pairs):
    '''
    given a dict with single virus index (v), and a list of UNIQUE human indices (hidxs) and 
    observed pairs (pairs) return a dataframe wit cols: vidx, hidx, edge(0/1)
    '''
    d = {'v_idx':[], 'h_idx':[], 'edge':[]}
    
    for h in human_idxs:
        d['v_idx'].append(v)
        d['h_idx'].append(h)
        
        if (v, h) in pairs:
            d['edge'].append(1.0)
        else:
            d['edge'].append(0.0)
    
#     print('vidx: ', v, 'npos: ', )
    
#     try:
#         return pd.DataFrame(d)

    df = pd.DataFrame(d)
    edges = df['edge'].values
    countdf = {'v_idx':[v], 'n_pos':[0], 'n_neg':[0], 'ratio':[0.0]}
    
    countdf['n_pos'][0] = len(edges[edges==1])
    countdf['n_neg'][0] = len(edges[edges==0])
    countdf['ratio'][0] = len(edges[edges==1])/len(edges)
    
    return pd.DataFrame(countdf)
#     except:
#         print(len(d['v_idx']), len(d['h_idx']), len(d['edge']))

def makedf(df):
    virus_idxs = df['v_idx'].values
    human_idxs = df['h_idx'].values
    
    # get all possible pairs
    pairs = [(v, h) for v, h in zip(virus_idxs, human_idxs)]

    virus_idxs_uniq = df['v_idx'].unique()
    human_idxs_uniq = df['h_idx'].unique()

    pool = mp.Pool(20)
    results = pool.starmap(mp_pairmatcher, 
                           [(v, human_idxs_uniq, pairs) for v in virus_idxs_uniq], 15)
    
#     return pd.concat(results).sample(frac=1) #concatenate 
    return pd.concat(results).reset_index()

# %%
flu_train = makedf(numdf)

# %%
flu_train = flu_train.sort_values(by='n_pos', ascending=False).reset_index()

# %%
flu_train.head()
# Out:
#    index  v_idx  n_pos  n_neg     ratio
# 0      0     32    721   1912  0.273832
# 1      0     31    716   1917  0.271933
# 2      0     33    666   1967  0.252943
# 3      0     36    613   2020  0.232814
# 4      0     15    553   2080  0.210027

# %%
flu_train.drop(columns=['index'])
# Out:
#      v_idx  n_pos  n_neg     ratio
# 0       32    721   1912  0.273832
# 1       31    716   1917  0.271933
# 2       33    666   1967  0.252943
# 3       36    613   2020  0.232814
# 4       15    553   2080  0.210027
# 5       37    396   2237  0.150399
# 6        4    389   2244  0.147740
# 7       35    376   2257  0.142803
# 8       14    356   2277  0.135207
# 9        8    350   2283  0.132928
# 10      30    344   2289  0.130649
# 11       2    334   2299  0.126852
# 12      51    314   2319  0.119256
# 13       9    298   2335  0.113179
# 14      47    292   2341  0.110900
# 15      10    291   2342  0.110520
# 16      11    223   2410  0.084694
# 17      12    207   2426  0.078618
# 18      42    193   2440  0.073300
# 19       0    169   2464  0.064185
# 20       1    153   2480  0.058109
# 21       6    130   2503  0.049373
# 22      34     89   2544  0.033802
# 23      50     88   2545  0.033422
# 24      25     74   2559  0.028105
# 25      43     70   2563  0.026586
# 26       7     67   2566  0.025446
# 27     137     49   2584  0.018610
# 28      52     49   2584  0.018610
# 29       3     41   2592  0.015572
# ..     ...    ...    ...       ...
# 111     56      1   2632  0.000380
# 112     57      1   2632  0.000380
# 113     64      1   2632  0.000380
# 114     61      1   2632  0.000380
# 115     81      1   2632  0.000380
# 116    121      1   2632  0.000380
# 117     72      1   2632  0.000380
# 118     74      1   2632  0.000380
# 119     54      1   2632  0.000380
# 120    107      1   2632  0.000380
# 121     96      1   2632  0.000380
# 122    130      1   2632  0.000380
# 123     84      1   2632  0.000380
# 124     95      1   2632  0.000380
# 125     73      1   2632  0.000380
# 126     99      1   2632  0.000380
# 127     92      1   2632  0.000380
# 128     77      1   2632  0.000380
# 129    138      1   2632  0.000380
# 130    112      1   2632  0.000380
# 131     85      1   2632  0.000380
# 132    102      1   2632  0.000380
# 133    116      1   2632  0.000380
# 134     98      1   2632  0.000380
# 135    123      1   2632  0.000380
# 136     16      1   2632  0.000380
# 137     66      1   2632  0.000380
# 138     58      1   2632  0.000380
# 139     67      1   2632  0.000380
# 140      5      1   2632  0.000380
#
# [141 rows x 4 columns]

# %%
flu_train[:28]
# Out:
#     index  v_idx  n_pos  n_neg     ratio
# 0       0     32    721   1912  0.273832
# 1       0     31    716   1917  0.271933
# 2       0     33    666   1967  0.252943
# 3       0     36    613   2020  0.232814
# 4       0     15    553   2080  0.210027
# 5       0     37    396   2237  0.150399
# 6       0      4    389   2244  0.147740
# 7       0     35    376   2257  0.142803
# 8       0     14    356   2277  0.135207
# 9       0      8    350   2283  0.132928
# 10      0     30    344   2289  0.130649
# 11      0      2    334   2299  0.126852
# 12      0     51    314   2319  0.119256
# 13      0      9    298   2335  0.113179
# 14      0     47    292   2341  0.110900
# 15      0     10    291   2342  0.110520
# 16      0     11    223   2410  0.084694
# 17      0     12    207   2426  0.078618
# 18      0     42    193   2440  0.073300
# 19      0      0    169   2464  0.064185
# 20      0      1    153   2480  0.058109
# 21      0      6    130   2503  0.049373
# 22      0     34     89   2544  0.033802
# 23      0     50     88   2545  0.033422
# 24      0     25     74   2559  0.028105
# 25      0     43     70   2563  0.026586
# 26      0      7     67   2566  0.025446
# 27      0    137     49   2584  0.018610

# %%
flu_train['ratio'][:16].mean() ## maybe experiment with not including extremely sparse strains
# Out:
# 0.16637390808963157

# %%
flu_train['ratio'].mean()
# Out:
# 0.024339197259011926

# %%
flu_top28 = flu_train[:28]

# %%
flu_top16 = flu_train[:16]

# %%
flu_top28['ratio'].mean()
# Out:
# 0.11557972980304919

# %%
flu_top16['ratio'].mean()
# Out:
# 0.16637390808963157

# %%
flu_top28['n_pos'].sum()
# Out:
# 8521

# %%
flu_top28['n_pos'].sum() + flu_top28['n_neg'].sum()
# Out:
# 73724

# %%
flu_top16['n_pos'].sum()
# Out:
# 7009

# %%
flu_train['n_pos'].sum()
# Out:
# 9036

# %%
flu_train['n_pos'].sum() + flu_train['n_neg'].sum()
# Out:
# 371253

# %%
9036 / 371253
# Out:
# 0.024339197259012048

# %%
len(flu_train['v_idx'].unique())
# Out:
# 141
