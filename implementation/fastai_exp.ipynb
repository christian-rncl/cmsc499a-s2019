# %%
import pandas as pd
from torch.utils import data
from fastaiv07.learner import *
import torch.nn.functional as F
import torch

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda

# %%
'''
Make random data for testing
'''
def make_colab_data(n, m, max_mIJ = 5):
    ratings = np.random.randint(max_mIJ, size=(n,m))
    
    data_dict = {'row':[], 'col':[], 'm_IJ':[]}
    
    for row in range(n):
        for col in range(m):
            data_dict['row'].append(row)
            data_dict['col'].append(col)
            data_dict['m_IJ'].append(ratings[row,col])
    
    return pd.DataFrame(data_dict)

# %%
class TestData(data.Dataset):

    def __init__(self, df):
        nonzero_entries = df.loc[df['m_IJ'] > 0].values
        self.index_pairs = []
        self.vals = []
        
        for row in nonzero_entries:
            self.index_pairs.append((row[0], row[1]))
            self.vals.append(float(row[2]))
            
            
    def __len__(self):
        return len(self.vals)
    
    def __getitem__(self, index):
        X = self.index_pairs[index]
        y = self.vals[index]
        
        return X, y

# %%
class EmbeddingDot(torch.nn.Module):
    def __init__(self, n_users, n_movies, n_factors=3):
        super().__init__()
        self.u = nn.Embedding(n_users, n_factors)
        self.m = nn.Embedding(n_movies, n_factors)
        self.u.weight.data.uniform_(0,0.05)
        self.m.weight.data.uniform_(0,0.05)
        
    def forward(self, indices):
        row,col = indices[0],indices[1]
        u,m = self.u(Variable(row)),self.m(Variable(col))
        return (u*m).sum(1).view(-1, 1)

# %%
def get_emb(ni,nf):
    e = nn.Embedding(ni, nf)
    e.weight.data.uniform_(-0.01,0.01)
    return e

class EmbeddingDotBias(nn.Module):
    def __init__(self, n_users, n_movies, n_factors=10):
        super().__init__()
        (self.u, self.m, self.ub, self.mb) = [get_emb(*o) for o in [
            (n_users, n_factors), (n_movies, n_factors), (n_users,1), (n_movies,1)
        ]]
        
    def forward(self, indices):
        users,movies = indices[0],indices[1]
        um = (self.u(users)* self.m(movies)).sum(1)
        res = um + self.ub(users).squeeze() + self.mb(movies).squeeze()
        res = torch.sigmoid(res) * (5-1) + 1
        return res.view(-1, 1)

# %%
class EmbeddingNet(nn.Module):
    def __init__(self, n_users, n_movies, n_factors=15, nh=10, p1=0.05, p2=0.5):
        super().__init__()
        (self.u, self.m) = [get_emb(*o) for o in [
            (n_users, n_factors), (n_movies, n_factors)]]
        self.lin1 = nn.Linear(n_factors*2, nh)
        self.lin2 = nn.Linear(nh, 1)
        self.drop1 = nn.Dropout(p1)
        self.drop2 = nn.Dropout(p2)
        
    def forward(self, indices):
        users,movies = indices[0],indices[1]
        x = self.drop1(torch.cat([self.u(users),self.m(movies)], dim=1))
        x = self.drop2(F.relu(self.lin1(x)))
        return torch.sigmoid(self.lin2(x)) * (5-0+1) + 0-0.5

# %%
print_every = 10
def train(model, opt, epochs=1):
    best_acc = -1

    
    for e in range(epochs):
        for c, (x, y) in enumerate(loader):
            model.train()

            pred = model(x)

#             criterion = nn.MSELoss()
            loss = F.mse_loss(pred, y.float())
            opt.zero_grad()
            loss.backward()

            opt.step()
            
#             if e % print_every == 0:
#                 print('Iteration %d, loss = %.4f' % (e, loss.item()))
#                 acc = check_accuracy_part34(loader_val, model)
#                 best_acc = acc if acc > best_acc else best_acc
            
    return best_acc

# %%
def check_accuracy_part34(loader, model):

    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    
    with torch.no_grad():
        for x, y in loader:
#             x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
#             y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            print(x, 'pred: ', scores, 'gt: ', y)
#             _, preds = scores.max(1)
#             num_correct += (preds == y.long()).sum()
#             num_samples += preds.size(0)
#         acc = float(num_correct) / num_samples
#         print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
#         return acc

# %%
params = {'batch_size': 1,
          'shuffle': True,
          'num_workers': 6}
epochs = 10
N = 25

df = make_colab_data(N,N)
testdata = TestData(df)
loader = data.DataLoader(testdata, **params)
# print(df.loc[df['m_IJ'] > 0].values)

# %%
wd=1e-5
model = EmbeddingDotBias(N, N, 20)
# model = EmbeddingNet(N, N, n_factors=15)
opt = optim.SGD(model.parameters(), 1e-3, weight_decay=wd, momentum=0.9)
train(model, opt, epochs=100)
# Out:
# -1

# %%
check_accuracy_part34(loader, model)
# Out:
# [tensor([7]), tensor([16])] pred:  tensor([[1.8489]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([23]), tensor([15])] pred:  tensor([[1.1616]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([6]), tensor([3])] pred:  tensor([[2.8771]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([14]), tensor([0])] pred:  tensor([[3.8926]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([12]), tensor([10])] pred:  tensor([[3.9327]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([19]), tensor([0])] pred:  tensor([[4.1929]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([21]), tensor([6])] pred:  tensor([[3.6199]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([1]), tensor([16])] pred:  tensor([[2.1444]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([3]), tensor([8])] pred:  tensor([[1.9841]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([6]), tensor([18])] pred:  tensor([[2.0524]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([20]), tensor([13])] pred:  tensor([[4.1136]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([15]), tensor([23])] pred:  tensor([[2.9854]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([22]), tensor([24])] pred:  tensor([[1.1474]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([3]), tensor([11])] pred:  tensor([[2.8900]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([0]), tensor([18])] pred:  tensor([[1.9597]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([22]), tensor([22])] pred:  tensor([[3.0791]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([1]), tensor([5])] pred:  tensor([[4.0223]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([24]), tensor([11])] pred:  tensor([[2.9192]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([12]), tensor([14])] pred:  tensor([[3.9481]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([12]), tensor([23])] pred:  tensor([[4.0931]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([2]), tensor([5])] pred:  tensor([[1.4894]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([20]), tensor([7])] pred:  tensor([[3.9165]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([24]), tensor([21])] pred:  tensor([[1.3458]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([23]), tensor([12])] pred:  tensor([[1.9240]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([20]), tensor([22])] pred:  tensor([[3.0374]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([10]), tensor([7])] pred:  tensor([[3.0014]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([14]), tensor([12])] pred:  tensor([[1.3127]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([0]), tensor([6])] pred:  tensor([[2.9106]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([12]), tensor([16])] pred:  tensor([[3.0258]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([15]), tensor([22])] pred:  tensor([[2.9492]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([3]), tensor([6])] pred:  tensor([[1.9573]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([22]), tensor([3])] pred:  tensor([[1.0517]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor
]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([16]), tensor([24])] pred:  tensor([[3.9461]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([13]), tensor([23])] pred:  tensor([[1.4062]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([15]), tensor([20])] pred:  tensor([[1.9260]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([7]), tensor([12])] pred:  tensor([[3.8666]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([7]), tensor([14])] pred:  tensor([[2.9437]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([1]), tensor([18])] pred:  tensor([[2.9183]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([15]), tensor([12])] pred:  tensor([[4.1320]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([22]), tensor([20])] pred:  tensor([[1.2302]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([19]), tensor([2])] pred:  tensor([[2.1876]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([17]), tensor([3])] pred:  tensor([[1.0806]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([0]), tensor([23])] pred:  tensor([[1.0592]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([6]), tensor([0])] pred:  tensor([[3.9551]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([3]), tensor([9])] pred:  tensor([[1.8386]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([0]), tensor([12])] pred:  tensor([[3.9447]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([3]), tensor([23])] pred:  tensor([[2.9681]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([5]), tensor([20])] pred:  tensor([[2.8702]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([3]), tensor([24])] pred:  tensor([[1.9458]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([17]), tensor([9])] pred:  tensor([[1.2799]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([0]), tensor([19])] pred:  tensor([[1.2383]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([10]), tensor([14])] pred:  tensor([[3.9717]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([13]), tensor([4])] pred:  tensor([[1.4231]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([19]), tensor([16])] pred:  tensor([[2.1154]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([0]), tensor([22])] pred:  tensor([[3.9376]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([23]), tensor([17])] pred:  tensor([[1.1589]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([3]), tensor([7])] pred:  tensor([[3.9028]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([18]), tensor([24])] pred:  tensor([[4.1229]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([5]), tensor([4])] pred:  tensor([[2.0344]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([13]), tensor([6])] pred:  tensor([[3.1668]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([10]), tensor([10])] pred:  tensor([[1.2361]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([4]), tensor([21])] pred:  tensor([[1.1582]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([7]), tensor([21])] pred:  tensor([[2.9474]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([4]), tensor([7])] pred:  tensor([[2.9244]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([1]), tensor([6])] pred:  tensor([[3.0616]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([10]), tensor([18])] pred:  tensor([[1.6108]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([4]), tensor([1])] pred:  tensor([[1.9218]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([11]), tensor([22])] pred:  tensor([[3.1243]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([23]), tensor([4])] pred:  tensor([[2.9234]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([14]), tensor([22])] pred:  tensor([[1.8966]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([13]), tensor([1])] pred:  tensor([[3.0946]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([3]), tensor([1])] pred:  tensor([[4.1012]]) gt:  tensor([4.], dtype=torch.float64)
# [tensor([3]), tensor([10])] pred:  tensor([[2.2309]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([24]), tensor([22])] pred:  tensor([[1.4769]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([9]), tensor([3])] pred:  tensor([[1.9020]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([19]), tensor([15])] pred:  tensor([[2.0523]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([3]), tensor([3])] pred:  tensor([[1.1445]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([19]), tensor([22])] pred:  tensor([[2.8070]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([14]), tensor([5])] pred:  tensor([[1.2761]]) gt:  tensor([1.], dtype=torch.float64)
# [tensor([6]), tensor([19])] pred:  tensor([[1.8583]]) gt:  tensor([2.], dtype=torch.float64)
# [tensor([23]), tensor([7])] pred:  tensor([[3.1384]]) gt:  tensor([3.], dtype=torch.float64)
# [tensor([11]), tensor([23])] pred:  tensor([[1.6970]]) gt:  tensor([2.], dtype=torch.float64)

# %%
print(df.loc[df['m_IJ'] > 0].values)
# Out:
# [[0 0 1]
#  [0 2 1]
#  [1 0 2]
#  [1 1 1]
#  [1 2 3]
#  [2 0 4]
#  [2 1 4]]
