# %% [markdown]
# # Global settings

# %%
device = 'cuda'
bs = 32

# %% [markdown]
# # Data proc

# %%
import pandas as pd
import numpy as np
import torch
import itertools
from make_matrix import *
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

# %%
df = pd.read_csv('data.txt', delim_whitespace=True, header=None)

# %%
df.head()
# Out:
#         0     1   2   3
# 0   STAT1  ATF3  71   3
# 1   STAT1  NFYB  71  85
# 2   STAT1   SP1  71  70
# 3  ZFP238  EGR1  15   8
# 4  ZFP238  IRF9  15  83

# %%
vs = df[2].unique()
hs = df[3].unique()

# %%
len(df)
# Out:
# 666

# %%
observed = []
for _, row in df.iterrows():
    observed.append((row[2], row[3]))

# %%
len(observed)
# Out:
# 666

# %%
net_df = {'vs':[], 'hs':[], 'edge':[]}

# %%
for v in vs:
    for h in hs:
        net_df['vs'].append(v)
        net_df['hs'].append(h)
        if (v,h) in observed:
            net_df['edge'].append(1.0)
        else:
            net_df['edge'].append(0.0)

# %%
netdf = pd.DataFrame(net_df)

# %%
len(netdf.loc[netdf['edge'] == 1])
# Out:
# 666

# %%
netdf = netdf.sample(frac=1).reset_index()[['vs', 'hs', 'edge']]

# %% [markdown]
# make sure indices are continuous

# %%
netdf.head()
# Out:
#    vs  hs  edge
# 0  85  20   1.0
# 1  94  35   0.0
# 2  53  94   1.0
# 3  93   0   0.0
# 4  44  81   1.0

# %%
vs.sort()
hs.sort()
vs_map = {v:i for i,v in enumerate(vs)}
hs_map = {h:i for i, h in enumerate(hs)}

# %%
netdf.vs = netdf.vs.apply(lambda x : vs_map[x])
netdf.hs = netdf.hs.apply(lambda x : hs_map[x])
netdf.head()
# Out:
#    vs  hs  edge
# 0  34  11   1.0
# 1  39  16   0.0
# 2  24  39   1.0
# 3  38   0   0.0
# 4  21  32   1.0

# %%
len(netdf.loc[netdf['edge'] == 1]) / len(netdf)
# Out:
# 0.41625

# %% [markdown]
# ### Make a dataloader

# %%
X = list(zip(netdf.vs.values, netdf.hs.values))

# %%
y = netdf['edge'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1)

# %%
def arr_to_torch(arr, dtype):
    t =  torch.from_numpy(np.array(arr)).type(dtype).to(device)
    return t

# %%
train_dset = TensorDataset(arr_to_torch(X_train, torch.long), arr_to_torch(y_train, torch.float32))
train_loader = DataLoader(train_dset, batch_size=bs)

# %%
val_dset = TensorDataset(arr_to_torch(X_val, torch.long), arr_to_torch(y_val, torch.float32))
val_loader = DataLoader(val_dset, batch_size=bs)

# %%
test_dset = TensorDataset(arr_to_torch(X_test, torch.long), arr_to_torch(y_test, torch.float32))
test_loader = DataLoader(test_dset, batch_size=bs)

# %% [markdown]
# # Model

# %%
def l2_regularize(array):
    loss = torch.sum(array ** 2.0)
    return loss

# %%
class MF(nn.Module):
    def __init__(self, n_virus, n_human, k=18, c_vector=1.0, c_bias=1.0, writer=None):
        super(MF, self).__init__()
        self.writer = writer
        self.k = k
        self.n_virus = n_virus
        self.n_human = n_human
        self.c_bias = c_bias
        self.c_vector = c_vector
        
        self.virus = nn.Embedding(n_virus, k)
        self.human = nn.Embedding(n_human, k)
        
        # We've added new terms here:
        self.bias_virus = nn.Embedding(n_virus, 1)
        self.bias_human = nn.Embedding(n_human, 1)
        self.bias = nn.Parameter(torch.ones(1))
        
#         self.affine = nn.Linear(in_features=self.k, out_features=1)
#         self.logistic = nn.Sigmoid()
    
    def forward(self, train_x):
        virus_id = train_x[:, 0]
        human_id = train_x[:, 1]
        vector_virus = self.virus(virus_id)
        vector_human = self.human(human_id)
        
        # Pull out biases
        bias_virus = self.bias_virus(virus_id).squeeze()
        bias_human = self.bias_human(human_id).squeeze()
        biases = (self.bias + bias_virus + bias_human)
        
        ui_interaction = torch.sum(vector_virus * vector_human, dim=1)
        
        prediction = ui_interaction + biases
        return prediction
    
    def loss(self, prediction, target):
#         loss_mse = F.binary_cross_entropy_with_logits(prediction, target.squeeze())
        loss_mse = F.mse_loss(prediction, target.squeeze())
    
        # Add new regularization to the biases
        prior_bias_virus =  l2_regularize(self.bias_virus.weight) * self.c_bias
        prior_bias_human = l2_regularize(self.bias_human.weight) * self.c_bias
        
        prior_virus =  l2_regularize(self.virus.weight.data) * self.c_vector
        prior_human = l2_regularize(self.human.weight.data) * self.c_vector
        total = loss_mse + prior_virus + prior_human + prior_bias_virus + prior_bias_human
        return total

# %% [markdown]
# # Trainer

# %%
from ignite.engine import Events, create_supervised_trainer, create_supervised_evaluator
from ignite.metrics import Loss, Accuracy, Precision, Recall
from tensorboardX import SummaryWriter
from ignite.metrics import MeanSquaredError, Loss
from ignite.contrib.metrics import AveragePrecision, ROC_AUC

from datetime import datetime

# %%
# Hyperparameters
lr = 1e-3
k =20
# New parameter for regularizing bias
c_bias = 1e-4
c_vector = 1e-4
batchsize = bs
log_dir = 'runs/simple_mf_02_bias_' + str(datetime.now()).replace(' ', '_')
print(log_dir)
# Out:
# runs/simple_mf_02_bias_2019-05-16_21:16:41.891986

# %%
writer = SummaryWriter(log_dir=log_dir)
# crit = model.loss
crit = nn.MSELoss()

model = MF(len(vs_map), len(hs_map), writer=writer, k=k, c_bias=c_bias, c_vector=c_vector)
# model.cuda()
optimizer = torch.optim.Adam(model.parameters())
trainer = create_supervised_trainer(model, optimizer, model.loss)
metrics = {'loss': Loss(crit), 'ap': AveragePrecision(), "acc": Accuracy(), "roc": ROC_AUC()}
evaluator = create_supervised_evaluator(model, metrics=metrics)

def log_training_loss(engine, log_interval=400):
    epoch = engine.state.epoch
    itr = engine.state.iteration
    fmt = "Epoch[{}] Iteration[{}/{}] Loss: {:.2f}"
    msg = fmt.format(epoch, itr, len(train_loader), engine.state.output)
    model.itr = itr
    if itr % log_interval == 0:
        print(msg)
        metrics = evaluator.state.metrics
        mse = metrics['loss']
        avg_precision = metrics['ap']
        accuracy = metrics['acc']
        roc = metrics['roc']
        writer.add_scalar("training/mse", mse, engine.state.epoch)
        writer.add_scalar("training/ap", avg_precision, engine.state.epoch)
        writer.add_scalar("training/accuracy", accuracy, engine.state.epoch)
        writer.add_scalar("training/roc", roc, engine.state.epoch)

trainer.add_event_handler(event_name=Events.ITERATION_COMPLETED, handler=log_training_loss)

def log_validation_results(engine):
    evaluator.run(val_loader)
    metrics = evaluator.state.metrics
    mse = metrics['loss']
    avg_precision = metrics['ap']
    accuracy = metrics['acc']
    roc = metrics['roc']
    print("Epoch[{}] Validation MSE: {:.2f} Avg Prec: {:.2f} acc: {:.2f} ROC: {:.2f} "
          .format(engine.state.epoch, mse, avg_precision, accuracy, roc))
    writer.add_scalar("validation/mse", mse, engine.state.epoch)
    writer.add_scalar("validation/avg_precision", avg_precision, engine.state.epoch)
    writer.add_scalar("validation/accuracy", accuracy, engine.state.epoch)
    writer.add_scalar("validation/roc", roc, engine.state.epoch)

    
def log_test_results(engine):
    evaluator.run(test_loader)
    metrics = evaluator.state.metrics
    mse = metrics['loss']
    avg_precision = metrics['ap']
    accuracy = metrics['acc']
    roc = metrics['roc']

    print("TEST: Epoch[{}] Validation MSE: {:.2f} Avg Prec: {:.2f} acc: {:.2f} ROC: {:.2f}"
          .format(engine.state.epoch, mse, avg_precision, accuracy, roc))


trainer.add_event_handler(event_name=Events.EPOCH_COMPLETED, handler=log_validation_results)
trainer.add_event_handler(event_name=Events.COMPLETED, handler=log_test_results)


model
# Out:
# MF(
#   (virus): Embedding(40, 20)
#   (human): Embedding(40, 20)
#   (bias_virus): Embedding(40, 1)
#   (bias_human): Embedding(40, 1)
# )

# %%
model.to(device)
# Out:
# MF(
#   (virus): Embedding(40, 20)
#   (human): Embedding(40, 20)
#   (bias_virus): Embedding(40, 1)
#   (bias_human): Embedding(40, 1)
# )

# %%
trainer.run(train_loader, max_epochs=500)
# Out:
# Epoch[1] Validation MSE: 24.27 Avg Prec: 0.46 acc: 0.08 ROC: 0.51
# Epoch[2] Validation MSE: 23.71 Avg Prec: 0.46 acc: 0.08 ROC: 0.51
# Epoch[3] Validation MSE: 23.17 Avg Prec: 0.46 acc: 0.08 ROC: 0.51
# Epoch[4] Validation MSE: 22.65 Avg Prec: 0.46 acc: 0.07 ROC: 0.51
# Epoch[5] Validation MSE: 22.15 Avg Prec: 0.46 acc: 0.08 ROC: 0.51
# Epoch[6] Validation MSE: 21.68 Avg Prec: 0.46 acc: 0.08 ROC: 0.51
# Epoch[7] Validation MSE: 21.22 Avg Prec: 0.46 acc: 0.07 ROC: 0.51
# Epoch[8] Validation MSE: 20.78 Avg Prec: 0.46 acc: 0.08 ROC: 0.51
# Epoch[9] Validation MSE: 20.36 Avg Prec: 0.46 acc: 0.09 ROC: 0.51
# Epoch[10] Iteration[400/41] Loss: 13.10
# Epoch[10] Validation MSE: 19.95 Avg Prec: 0.46 acc: 0.10 ROC: 0.51
# Epoch[11] Validation MSE: 19.56 Avg Prec: 0.46 acc: 0.10 ROC: 0.51
# Epoch[12] Validation MSE: 19.18 Avg Prec: 0.46 acc: 0.11 ROC: 0.51
# Epoch[13] Validation MSE: 18.82 Avg Prec: 0.46 acc: 0.10 ROC: 0.51
# Epoch[14] Validation MSE: 18.47 Avg Prec: 0.46 acc: 0.10 ROC: 0.51
# Epoch[15] Validation MSE: 18.13 Avg Prec: 0.46 acc: 0.10 ROC: 0.51
# Epoch[16] Validation MSE: 17.81 Avg Prec: 0.46 acc: 0.10 ROC: 0.51
# Epoch[229] Validation MSE: 1.65 Avg Prec: 0.51 acc: 0.38 ROC: 0.57
# Epoch[230] Validation MSE: 1.64 Avg Prec: 0.51 acc: 0.38 ROC: 0.57
# Epoch[231] Validation MSE: 1.63 Avg Prec: 0.51 acc: 0.38 ROC: 0.57
# Epoch[232] Validation MSE: 1.62 Avg Prec: 0.51 acc: 0.38 ROC: 0.57
# Epoch[233] Validation MSE: 1.61 Avg Prec: 0.51 acc: 0.38 ROC: 0.57
# Epoch[234] Validation MSE: 1.60 Avg Prec: 0.51 acc: 0.38 ROC: 0.57
# Epoch[235] Iteration[9600/41] Loss: 0.14
# Epoch[235] Validation MSE: 1.60 Avg Prec: 0.51 acc: 0.39 ROC: 0.57
# Epoch[236] Validation MSE: 1.59 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[237] Validation MSE: 1.58 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[238] Validation MSE: 1.57 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[239] Validation MSE: 1.57 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[240] Validation MSE: 1.56 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[241] Validation MSE: 1.55 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[242] Validation MSE: 1.55 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[243] Validation MSE: 1.54 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[244] Iteration[10000/41] Loss: 0.12
# Epoch[244] Validation MSE: 1.53 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[245] Validation MSE: 1.53 Avg Prec: 0.51 acc: 0.40 ROC: 0.57
# Epoch[246] Validation MSE: 1.52 Avg Prec: 0.52 acc: 0.40 ROC: 0.57
# Epoch[247] Validation MSE: 1.51 Avg Prec: 0.52 acc: 0.40 ROC: 0.57
# Epoch[248] Validation MSE: 1.51 Avg Prec: 0.52 acc: 0.40 ROC: 0.57
# Epoch[249] Validation MSE: 1.50 Avg Prec: 0.52 acc: 0.40 ROC: 0.57
# Epoch[250] Validation MSE: 1.50 Avg Prec: 0.52 acc: 0.40 ROC: 0.58
# Epoch[251] Validation MSE: 1.49 Avg Prec: 0.52 acc: 0.40 ROC: 0.58
# Epoch[252] Validation MSE: 1.48 Avg Prec: 0.52 acc: 0.40 ROC: 0.58
# Epoch[253] Validation MSE: 1.48 Avg Prec: 0.52 acc: 0.39 ROC: 0.58
# Epoch[254] Iteration[10400/41] Loss: 0.13
# Epoch[254] Validation MSE: 1.47 Avg Prec: 0.51 acc: 0.39 ROC: 0.58
# Epoch[255] Validation MSE: 1.47 Avg Prec: 0.52 acc: 0.40 ROC: 0.58
# Epoch[256] Validation MSE: 1.46 Avg Prec: 0.52 acc: 0.40 ROC: 0.58
# Epoch[257] Validation MSE: 1.46 Avg Prec: 0.52 acc: 0.40 ROC: 0.58
# Epoch[258] Validation MSE: 1.45 Avg Prec: 0.52 acc: 0.39 ROC: 0.58
# Epoch[351] Validation MSE: 1.27 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[352] Iteration[14400/41] Loss: 0.10
# Epoch[352] Validation MSE: 1.27 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[353] Validation MSE: 1.27 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[354] Validation MSE: 1.27 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[355] Validation MSE: 1.27 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[356] Validation MSE: 1.27 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[357] Validation MSE: 1.27 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[358] Validation MSE: 1.27 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[359] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.46 ROC: 0.59
# Epoch[360] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.46 ROC: 0.59
# Epoch[361] Iteration[14800/41] Loss: 0.12
# Epoch[361] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.46 ROC: 0.59
# Epoch[362] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.46 ROC: 0.59
# Epoch[363] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.46 ROC: 0.59
# Epoch[364] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.46 ROC: 0.59
# Epoch[365] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.46 ROC: 0.59
# Epoch[366] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.46 ROC: 0.59
# Epoch[367] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[368] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.44 ROC: 0.59
# Epoch[369] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[370] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[371] Iteration[15200/41] Loss: 0.10
# Epoch[371] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[372] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.60
# Epoch[373] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[374] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[375] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[376] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[377] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[378] Validation MSE: 1.26 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[379] Validation MSE: 1.25 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[380] Validation MSE: 1.25 Avg Prec: 0.54 acc: 0.45 ROC: 0.59
# Epoch[411] Validation MSE: 1.24 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[412] Validation MSE: 1.24 Avg Prec: 0.54 acc: 0.47 ROC: 0.60
# Epoch[413] Validation MSE: 1.24 Avg Prec: 0.54 acc: 0.47 ROC: 0.60
# Epoch[414] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.47 ROC: 0.60
# Epoch[415] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.47 ROC: 0.60
# Epoch[416] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[417] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[418] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[419] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[420] Iteration[17200/41] Loss: 0.11
# Epoch[420] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[421] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[422] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[423] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[424] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[425] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[426] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[427] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[428] Validation MSE: 1.23 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[429] Validation MSE: 1.22 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[430] Iteration[17600/41] Loss: 0.10
# Epoch[430] Validation MSE: 1.22 Avg Prec: 0.54 acc: 0.48 ROC: 0.60
# Epoch[431] Validation MSE: 1.22 Avg Prec: 0.54 acc: 0.49 ROC: 0.60
# Epoch[432] Validation MSE: 1.22 Avg Prec: 0.54 acc: 0.49 ROC: 0.60
# Epoch[433] Validation MSE: 1.22 Avg Prec: 0.54 acc: 0.49 ROC: 0.60
# Epoch[434] Validation MSE: 1.22 Avg Prec: 0.54 acc: 0.49 ROC: 0.60
# Epoch[435] Validation MSE: 1.22 Avg Prec: 0.54 acc: 0.49 ROC: 0.60
# Epoch[436] Validation MSE: 1.22 Avg Prec: 0.54 acc: 0.49 ROC: 0.60
# Epoch[437] Validation MSE: 1.22 Avg Prec: 0.53 acc: 0.49 ROC: 0.60
# Epoch[438] Validation MSE: 1.22 Avg Prec: 0.53 acc: 0.49 ROC: 0.60
# Epoch[439] Validation MSE: 1.22 Avg Prec: 0.53 acc: 0.49 ROC: 0.60
# Epoch[440] Iteration[18000/41] Loss: 0.10
# Epoch[440] Validation MSE: 1.22 Avg Prec: 0.53 acc: 0.49 ROC: 0.60
# Epoch[441] Validation MSE: 1.22 Avg Prec: 0.53 acc: 0.49 ROC: 0.60
# Epoch[442] Validation MSE: 1.22 Avg Prec: 0.53 acc: 0.48 ROC: 0.60
# Epoch[443] Validation MSE: 1.22 Avg Prec: 0.53 acc: 0.48 ROC: 0.60
# Epoch[444] Validation MSE: 1.21 Avg Prec: 0.53 acc: 0.48 ROC: 0.60
# Epoch[445] Validation MSE: 1.21 Avg Prec: 0.53 acc: 0.48 ROC: 0.60
# Epoch[446] Validation MSE: 1.21 Avg Prec: 0.53 acc: 0.48 ROC: 0.60
# Epoch[447] Validation MSE: 1.21 Avg Prec: 0.53 acc: 0.48 ROC: 0.60
# Epoch[448] Validation MSE: 1.21 Avg Prec: 0.52 acc: 0.48 ROC: 0.60
# Epoch[449] Iteration[18400/41] Loss: 0.09
# Epoch[449] Validation MSE: 1.21 Avg Prec: 0.52 acc: 0.47 ROC: 0.60
# Epoch[450] Validation MSE: 1.21 Avg Prec: 0.52 acc: 0.47 ROC: 0.60
# Epoch[451] Validation MSE: 1.21 Avg Prec: 0.52 acc: 0.47 ROC: 0.60
# Epoch[452] Validation MSE: 1.21 Avg Prec: 0.52 acc: 0.47 ROC: 0.60
# Epoch[453] Validation MSE: 1.21 Avg Prec: 0.52 acc: 0.47 ROC: 0.60
# Epoch[454] Validation MSE: 1.21 Avg Prec: 0.52 acc: 0.47 ROC: 0.60
# Epoch[455] Validation MSE: 1.21 Avg Prec: 0.52 acc: 0.47 ROC: 0.60
# Epoch[456] Validation MSE: 1.21 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[457] Validation MSE: 1.21 Avg Prec: 0.52 acc: 0.47 ROC: 0.60
# Epoch[458] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[459] Iteration[18800/41] Loss: 0.11
# Epoch[459] Validation MSE: 1.20 Avg Prec: 0.52 acc: 0.47 ROC: 0.60
# Epoch[460] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[461] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[462] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[463] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[464] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[465] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[466] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[467] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[468] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[469] Iteration[19200/41] Loss: 0.09
# Epoch[469] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[470] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
# Epoch[471] Validation MSE: 1.20 Avg Prec: 0.53 acc: 0.47 ROC: 0.60
